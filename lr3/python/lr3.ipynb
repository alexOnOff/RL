# %%
import matplotlib.pyplot as plt

# %%
with open('../../bin/data.txt') as f:
    values = f.read().split(' ')

values.pop()
values.pop()
print(values)
# Out:
# ['0', '1', '0', '3', '4', '5', '0', '7', '8', '9', '10', '11', '12', '13', '11', '15', '9', '17', '18', '6', '5', '4', '22', '2', '24', '0', '26', '2', '28', '4', '5', '0', '7', '33', '9', '10', '11', '12', '12', '0', '10', '9', '8', '7', '0', '5', '4', '0', '2', '1', '0', '1', '2', '0', '4', '5', '0', '7', '8', '9', '10', '11', '12', '12', '0', '15', '9', '17', '18', '0', '5', '4', '0', '2', '1', '0', '1', '2', '0', '4', '5', '6', '0', '8', '9', '10', '0', '12', '12', '0', '10', '0', '8', '0', '6', '5', '4', '3', '2', '1']

# %%
plt.plot( values)
#plt.ylabel('Оценка ценности')
#plt.yscale('linear')
#plt.xlim(0, 100)
#plt.ylim(0, 50)
plt.show()
